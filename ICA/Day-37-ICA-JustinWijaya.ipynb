# %% [markdown]
# In order to successfully complete this assignment you need to participate both individually and in groups during class.   Have one of the instructors check your notebook and sign you out before leaving class. Turn in your assignment using D2L.

# %% [markdown]
# ---

# %% [markdown]
# # ICA 37: Presentation Planning
#
# <img src="https://freerangestock.com/sample/118608/whiteboard-icon-vector.jpg" width=50%>

# %% [markdown]
# ### Agenda for today's class (70 minutes)
#
# </p>
#
# 1. (70 minutes) Presentation Planning

# %% [markdown]
# ----
#
# # 1. Presentation Planning
#
# The project presentations are coming up next week, so lets use today's class to start planning the presentations. Remember, you are free to present your work in any format you would like as long as the presentation is kept to <5 minutes. The goal of the presentation is to show the rest of the class what you accomplished.

# %% [markdown]
# &#9989; **<font color=red>QUESTION:</font>** What format are you thinking of using? What will best convey your story? (Examples: Slides, live code demo, recorded code demo, poster, etc.)

# %% [markdown]
# - I'm planning on using a slide deck.

# %% [markdown]
# &#9989; **<font color=red>DO THIS:</font>** What is the primary goal of your talk? Write a 1-2 sentence "sales pitch" of what you want someone to take away from your presentation.

# %% [markdown]
# - The goal is to tell people about PyTorch and what using it will do for your performance.

# %% [markdown]
# &#9989; **<font color=red>DO THIS:</font>** State your "sales pitch" to your group. Was it clear to them what your project is about? If not, consider how you can clarify your point. It is very easy to fall into expert bias, where you assume everyone knows what you are talking about since you have been focused on it for so long. Your should present the work in a way that anyone with some knowledge of parallel computing can easily follow along.

# %% [markdown]
# - Mention what PyTorch does and the scaling tests done.

# %% [markdown]
# &#9989; **<font color=red>DO THIS:</font>** What are some things you need to include in your presentation? Create a list of essential things to include. Examples: Plot to show the scaling study results, figure/statistic on performance enhancement, image of the code output to show the quality improved, etc.

# %% [markdown]
# _Item 1_: Runtime benchmark plots to showcase speed performance.
#
# _Item 2_: Sample images from dataset with labels to introduce dataset and image classification as a whole.
#
# _Item 3_: Accuracy benchmark plots to display model performance.

# %% [markdown]
# &#9989; **<font color=red>DO THIS:</font>** Now take a few minutes to create a mind map/story board for your presentation. Map out the story you would like to tell and how much time you plan to spend on each part. (Feel free to draw this out on paper or use a digital tool.)

# %% [markdown]
# 1. PyTorch abstract
# 2. Breakdown of test program
# 3. Introduction to datasets*
# 4. Benchmark plots*
# 5. Conclusion
# *May take these slides and split them to individually discuss the 2 datasets.

# %% [markdown]
# &#9989; **<font color=red>DO THIS:</font>** Now that you have a story planned out, start pulling together the figures or resources you will need for your presentation. Having the key figures ready up front will make it much easier to prepare the story and discussion for the presentation.

# %% [markdown]
# &#9989; **<font color=red>DO THIS:</font>** (Time-permitting) Walk through any the resources you prepared with your group. See if they can easily understand the story you are trying to communicate. If not, try to figure out what was confusing/unclear and use that to revise how you communicate your work.

# %% [markdown]
# -----
# ### Congratulations, we're done!
#
# Have one of the instructors check your notebook and sign you out before leaving class. Turn in your assignment using D2L.

# %% [markdown]
# Written by Dr. Nathan Haut, Michigan State University
# <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc/4.0/">Creative Commons Attribution-NonCommercial 4.0 International License</a>.

# %% [markdown]
# ----
